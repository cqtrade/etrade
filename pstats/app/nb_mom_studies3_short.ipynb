# %%
# import talib
import numpy as np
# import pandas as pd
from backtesting_mom.signals3 import params_short, compute_signals_short
from backtesting.utils_compact import compact_all_medians, compact_best_medians
import warnings
warnings.simplefilter('ignore')
# Out:
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(

# %%
interval = '1h'
direction = 'short'
symbols = [
    "BTCUSDT",
    "ETHUSDT",
    "XRPUSDT",
    "SOLUSDT",
    "BNBUSDT",
    "DOGEUSDT",
    "ADAUSDT",
    "LINKUSDT",
    "AVAXUSDT",
    "SUIUSDT",
    "SHIBUSDT",
    "LTCUSDT",
    "HBARUSDT",
    "RENDERUSDT",
    "UNIUSDT",
]

# %%
params = params_short()
print(params.keys())
# Out:
# Number of permutations params_long: 3840
# dict_keys(['adx_p', 'adx_low', 'adx_high', 'fastperiod', 'slowperiod', 'signalperiod'])

# %%
medians_df, ohlc_dict, count_bars = compact_all_medians(
    symbols,
    interval,
    params,
    compute_signals_short,
)
# Out:
# Available pools -1: 15
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing signals for XRPUSDT
# Start computing signals for SOLUSDT
# Start computing signals for ETHUSDT
# Start computing signals for BTCUSDT
# Start computing signals for SHIBUSDT
# Start computing signals for UNIUSDT
# Start computing signals for BNBUSDT
# Start computing signals for RENDERUSDT
# Start computing signals for DOGEUSDT
# Start computing signals for HBARUSDT
# Start computing signals for SUIUSDT
# Start computing signals for AVAXUSDT
# Start computing signals for LINKUSDT
# Start computing signals for LTCUSDT
# Start computing signals for ADAUSDT
# End computing signals for RENDERUSDT
# End computing signals for BTCUSDT
# End computing signals for SOLUSDT
# End computing signals for ETHUSDT
# End computing signals for HBARUSDT
# End computing signals for LTCUSDT
# End computing signals for XRPUSDT
# End computing signals for LINKUSDT
# End computing signals for ADAUSDT
# End computing signals for SUIUSDT
# End computing signals for SHIBUSDT
# End computing signals for BNBUSDT
# End computing signals for UNIUSDT
# End computing signals for DOGEUSDT
# End computing signals for AVAXUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for ETHUSDT
# Start computing portfolio metrics for BTCUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for XRPUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for SOLUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for BNBUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for DOGEUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for ADAUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for LINKUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for AVAXUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for SUIUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for SHIBUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for LTCUSDT
# End computing portfolio metrics for BTCUSDT
# End computing portfolio metrics for ETHUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# End computing portfolio metrics for XRPUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for HBARUSDT
# Start computing portfolio metrics for RENDERUSDT
# End computing portfolio metrics for SOLUSDT
# End computing portfolio metrics for BNBUSDT
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing portfolio metrics for UNIUSDT
# End computing portfolio metrics for DOGEUSDT
# End computing portfolio metrics for ADAUSDT
# End computing portfolio metrics for LINKUSDT
# End computing portfolio metrics for AVAXUSDT
# End computing portfolio metrics for SUIUSDT
# End computing portfolio metrics for RENDERUSDT
# End computing portfolio metrics for SHIBUSDT
# End computing portfolio metrics for LTCUSDT
# End computing portfolio metrics for HBARUSDT
# End computing portfolio metrics for UNIUSDT

# %%
print(count_bars)
# Out:
# 8784

# %%
joined_long_df = medians_df.copy()
joined_long_df = joined_long_df.replace([np.inf, -np.inf], np.nan)
joined_long_df = joined_long_df.dropna()
# remove with negative total return
# joined_long_df = joined_long_df[joined_long_df['total_return'] > 0]
# joined_long_df = joined_long_df[joined_long_df > joined_long_df.quantile(0.45)]
joined_long_df = joined_long_df.dropna()
print(joined_long_df.describe())
# joined_long_df.sort_values(by='win_rate', ascending=False)
# joined_long_df.reset_index().to_csv(f'results_{direction}_{interval}_{count_bars}.csv', index=False)
joined_long_df = joined_long_df.sort_values(by='expectancy', ascending=False).head(55)
joined_long_df.head(10)
# Out:
#        total_return     win_rate        count  profit_factor  max_drawdown  \
# count   3840.000000  3840.000000  3840.000000    3840.000000   3840.000000
# mean      -0.116829     0.577363    59.178125       0.569159     -0.134429
# std        0.027823     0.021894    11.176415       0.051100      0.024064
# min       -0.175098     0.519231    35.000000       0.449014     -0.181956
# 25%       -0.137756     0.563636    51.000000       0.538281     -0.152915
# 50%       -0.114843     0.576923    60.000000       0.566275     -0.136860
# 75%       -0.094082     0.594595    67.250000       0.607721     -0.116863
# max       -0.061433     0.622642    79.000000       0.684646     -0.074189
#
#         expectancy
# count  3840.000000
# mean     -2.070711
# std       0.321898
# min      -2.950897
# 25%      -2.235429
# 50%      -2.068313
# 75%      -1.837755
# max      -1.394054
#                                                                                          total_return  \
# long_adx_p long_adx_low long_adx_high long_fastperiod long_slowperiod long_signalperiod
# 18         20           30            12              30              9                     -0.098295
#                         34            12              30              9                     -0.098295
#                         38            20              22              6                     -0.098295
#                         42            8               30              12                    -0.098295
#                         38            12              26              9                     -0.098295
#                         30            8               30              12                    -0.098295
#                         34            20              22              6                     -0.098295
#                         38            8               30              12                    -0.098295
#                         42            12              26              9                     -0.098295
#                         38            16              22              6                     -0.091887
#
#                                                                                          win_rate  \
# long_adx_p long_adx_low long_adx_high long_fastperiod long_slowperiod long_signalperiod
# 18         20           30            12              30              9                  0.622642
#                         34            12              30              9                  0.622642
#                         38            20              22              6                  0.622642
#                         42            8               30              12                 0.622642
#                         38            12              26              9                  0.622642
#                         30            8               30              12                 0.622642
#                         34            20              22              6                  0.622642
#                         38            8               30              12                 0.622642
#                         42            12              26              9                  0.622642
#                         38            16              22              6                  0.622642
#
#                                                                                          count  \
# long_adx_p long_adx_low long_adx_high long_fastperiod long_slowperiod long_signalperiod
# 18         20           30            12              30              9                   61.0
#                         34            12              30              9                   61.0
#                         38            20              22              6                   61.0
#                         42            8               30              12                  61.0
#                         38            12              26              9                   60.0
#                         30            8               30              12                  61.0
#                         34            20              22              6                   61.0
#                         38            8               30              12                  61.0
#                         42            12              26              9                   60.0
#                         38            16              22              6                   59.0
#
#                                                                                          profit_factor  \
# long_adx_p long_adx_low long_adx_high long_fastperiod long_slowperiod long_signalperiod
# 18         20           30            12              30              9                       0.684646
#                         34            12              30              9                       0.684646
#                         38            20              22              6                       0.684646
#                         42            8               30              12                      0.684646
#                         38            12              26              9                       0.684646
#                         30            8               30              12                      0.684646
#                         34            20              22              6                       0.684646
#                         38            8               30              12                      0.684646
#                         42            12              26              9                       0.684646
#                         38            16              22              6                       0.684646
#
#                                                                                          max_drawdown  \
# long_adx_p long_adx_low long_adx_high long_fastperiod long_slowperiod long_signalperiod
# 18         20           30            12              30              9                     -0.128411
#                         34            12              30              9                     -0.128411
#                         38            20              22              6                     -0.128411
#                         42            8               30              12                    -0.128411
#                         38            12              26              9                     -0.128411
#                         30            8               30              12                    -0.128411
#                         34            20              22              6                     -0.128411
#                         38            8               30              12                    -0.128411
#                         42            12              26              9                     -0.128411
#                         38            16              22              6                     -0.121679
#
#                                                                                          expectancy
# long_adx_p long_adx_low long_adx_high long_fastperiod long_slowperiod long_signalperiod
# 18         20           30            12              30              9                   -1.394054
#                         34            12              30              9                   -1.394054
#                         38            20              22              6                   -1.394054
#                         42            8               30              12                  -1.394054
#                         38            12              26              9                   -1.394054
#                         30            8               30              12                  -1.394054
#                         34            20              22              6                   -1.394054
#                         38            8               30              12                  -1.394054
#                         42            12              26              9                   -1.394054
#                         38            16              22              6                   -1.394054

# %%
dfc = joined_long_df.copy()
joined_best_orig_df, pf_dict = compact_best_medians(
    dfc,
    symbols,
    ohlc_dict,
    compute_signals_short,
)
# Out:
# Available pools -1: 15
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# /Users/sandermets/Projects/hobby/etrade/pstats/env/lib/python3.12/site-packages/telegram/utils/request.py:54: UserWarning: python-telegram-bot wasn't properly installed. Please refer to README.rst on how to properly install.
#   warnings.warn(
# Start computing signals for LTCUSDT
# Start computing signals for XRPUSDT
# Start computing signals for SHIBUSDT
# Start computing signals for SUIUSDT
# Start computing signals for UNIUSDT
# Start computing signals for ADAUSDT
# Start computing signals for BNBUSDT
# Start computing signals for RENDERUSDT
# Start computing signals for ETHUSDT
# Start computing signals for SOLUSDT
# Start computing signals for HBARUSDT
# Start computing signals for LINKUSDT
# Start computing signals for BTCUSDT
# Start computing signals for AVAXUSDT
# Start computing signals for DOGEUSDT
# End computing signals for RENDERUSDT
# End computing signals for BTCUSDT
# End computing signals for ETHUSDT
# End computing signals for DOGEUSDT
# End computing signals for ADAUSDT
# End computing signals for SHIBUSDT
# End computing signals for XRPUSDT
# End computing signals for AVAXUSDT
# End computing signals for LTCUSDT
# End computing signals for HBARUSDT
# End computing signals for SUIUSDT
# End computing signals for LINKUSDT
# End computing signals for BNBUSDT
# End computing signals for UNIUSDT
# End computing signals for SOLUSDT
# Start computing portfolio for BTCUSDT
# End computing portfolio for BTCUSDT
# Start computing portfolio for ETHUSDT
# End computing portfolio for ETHUSDT
# Start computing portfolio for XRPUSDT
# End computing portfolio for XRPUSDT
# Start computing portfolio for SOLUSDT
# End computing portfolio for SOLUSDT
# Start computing portfolio for BNBUSDT
# End computing portfolio for BNBUSDT
# Start computing portfolio for DOGEUSDT
# End computing portfolio for DOGEUSDT
# Start computing portfolio for ADAUSDT
# End computing portfolio for ADAUSDT
# Start computing portfolio for LINKUSDT
# End computing portfolio for LINKUSDT
# Start computing portfolio for AVAXUSDT
# End computing portfolio for AVAXUSDT
# Start computing portfolio for SUIUSDT
# End computing portfolio for SUIUSDT
# Start computing portfolio for SHIBUSDT
# End computing portfolio for SHIBUSDT
# Start computing portfolio for LTCUSDT
# End computing portfolio for LTCUSDT
# Start computing portfolio for HBARUSDT
# End computing portfolio for HBARUSDT
# Start computing portfolio for RENDERUSDT
# End computing portfolio for RENDERUSDT
# Start computing portfolio for UNIUSDT
# End computing portfolio for UNIUSDT

# %%
joined_best_df = joined_best_orig_df.copy()
# joined_df.sort_values(by='expectancy', ascending=False)
joined_best_df
joined_best_df = joined_best_df.replace([np.inf, -np.inf], np.nan)
joined_best_df = joined_best_df.dropna()
# joined_df = joined_df[joined_df > joined_df.quantile(0.35)]
joined_best_df = joined_best_df.dropna()
# # print(joined_df.describe())

# # drop multiindex and save to csv
# # joined_df.reset_index().to_csv(f'results_{direction}_{interval}_{count_bars}.csv', index=False)
joined_best_df = joined_best_df.sort_values(by='expectancy', ascending=False).head(5)
joined_best_df.head(4)
# Out:
#                                                                                          total_return  \
# long_adx_p long_adx_low long_adx_high long_fastperiod long_slowperiod long_signalperiod
# 18         20           30            16              22              6                     -0.091887
#                         42            16              22              6                     -0.091887
#                         38            16              22              6                     -0.091887
#                         34            16              22              6                     -0.091887
#
#                                                                                          win_rate  \
# long_adx_p long_adx_low long_adx_high long_fastperiod long_slowperiod long_signalperiod
# 18         20           30            16              22              6                  0.622642
#                         42            16              22              6                  0.622642
#                         38            16              22              6                  0.622642
#                         34            16              22              6                  0.622642
#
#                                                                                          count  \
# long_adx_p long_adx_low long_adx_high long_fastperiod long_slowperiod long_signalperiod
# 18         20           30            16              22              6                   59.0
#                         42            16              22              6                   59.0
#                         38            16              22              6                   59.0
#                         34            16              22              6                   59.0
#
#                                                                                          profit_factor  \
# long_adx_p long_adx_low long_adx_high long_fastperiod long_slowperiod long_signalperiod
# 18         20           30            16              22              6                       0.684646
#                         42            16              22              6                       0.684646
#                         38            16              22              6                       0.684646
#                         34            16              22              6                       0.684646
#
#                                                                                          max_drawdown  \
# long_adx_p long_adx_low long_adx_high long_fastperiod long_slowperiod long_signalperiod
# 18         20           30            16              22              6                     -0.121679
#                         42            16              22              6                     -0.121679
#                         38            16              22              6                     -0.121679
#                         34            16              22              6                     -0.121679
#
#                                                                                          expectancy
# long_adx_p long_adx_low long_adx_high long_fastperiod long_slowperiod long_signalperiod
# 18         20           30            16              22              6                   -1.394054
#                         42            16              22              6                   -1.394054
#                         38            16              22              6                   -1.394054
#                         34            16              22              6                   -1.394054

# %%
idxs = [0]
for idx in idxs:
   for symbol in symbols:
      pf = pf_dict[symbol].copy()
      print("#########################")
      # print(symbol)
      # pf[joined_best_df.index[idx]].plot_cum_returns().show_svg()
      win_rate = pf.trades[joined_best_df.index[idx]].win_rate()
      print(symbol, f"{round(win_rate*100, 2)}%")
      pf.trades[joined_best_df.index[idx]].plots(settings=dict(plot_zones=False)).show_svg()
      print("#########################")
# Out:
# #########################
# BTCUSDT 56.14%
# #########################
# #########################
# ETHUSDT 67.24%
# #########################
# #########################
# XRPUSDT 63.16%
# #########################
# #########################
# SOLUSDT 55.74%
# #########################
# #########################
# BNBUSDT 66.67%
# #########################
# #########################
# DOGEUSDT 59.32%
# #########################
# #########################
# ADAUSDT 67.69%
# #########################
# #########################
# LINKUSDT 52.46%
# #########################
# #########################
# AVAXUSDT 54.69%
# #########################
# #########################
# SUIUSDT 63.01%
# #########################
# #########################
# SHIBUSDT 63.01%
# #########################
# #########################
# LTCUSDT 56.92%
# #########################
# #########################
# HBARUSDT 68.97%
# #########################
# #########################
# RENDERUSDT 47.06%
# #########################
# #########################
# UNIUSDT 62.26%
# #########################
